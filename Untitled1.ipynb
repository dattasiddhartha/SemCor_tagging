# %%
from nltk.corpus import semcor

# %%
import pandas as pd
senses=pd.read_csv("sense_export_2.csv")
sentences=pd.read_json("export_file.json").T

# %%
correct_term2=[]
for i in range(len(sentences)):
    correct_term2.append(sentences.iloc[i,0].replace(",","").replace("'","").replace('"',"").replace('[',"").replace(']',""))
sentences['correct_term']=correct_term2

# %%
sentences.head()
# Out:
#                   0                                                  1  \
# 0         'mounds',                                             [4098]
# 1  'vulnerability',         [13638, 13639, 13640, 30648, 30685, 30686]
# 2       'outlying',                                     [17462, 26925]
# 3      'delegated',                              [16894, 34405, 35521]
# 4     'previously',  [160, 1433, 2007, 3144, 3286, 3766, 3919, 4751...
#
#     correct_term
# 0         mounds
# 1  vulnerability
# 2       outlying
# 3      delegated
# 4     previously

# %%
senses.head()
# Out:
#    Unnamed: 0                           0
# 0           0          'group.n.01.group'
# 1           1            'state.v.01.say'
# 2           2        'friday.n.01.Friday'
# 3           3  'probe.n.01.investigation'
# 4           4      'atlanta.n.01.Atlanta'

# %%
fulllist=[]
for item in sentences['correct_term']:
    templist=[]
    for sense in senses['0']:
        if item in sense:
            templist.append(sense)
    fulllist.append(templist)

# %%
fulllist
# Out:
# [[],
#  ["'vulnerability.n.01.vulnerability'",
#   "'vulnerability.n.01.vulnerability'",
#   "'vulnerability.n.01.vulnerability'"]]

# %%
sentences['sense_tag_list']=fulllist

# %%
sentences.to_csv("sentences_taggedsense.csv")

# %%
sentences.head()[1]
# Out:
# 0                                               [4098]
# 1           [13638, 13639, 13640, 30648, 30685, 30686]
# 2                                       [17462, 26925]
# 3                                [16894, 34405, 35521]
# 4    [160, 1433, 2007, 3144, 3286, 3766, 3919, 4751...
# Name: 1, dtype: object

# %%
cdi=pd.read_csv("cdi_WS_wordNetSenses.csv")
# cdi=cdi.iloc[15:19,:]

# %%
# senses['0'].head()
cdi
# Out:
#       Unnamed: 0    word  sense_index                   name  \
# 0              0   vroom            0             vroom.n.01
# 1              1   vroom            1             vroom.v.01
# 2              0    duck            0              duck.n.01
# 3              1    duck            1              duck.n.02
# 4              2    duck            2              duck.n.03
# 5              3    duck            3              duck.n.04
# 6              4    duck            4              duck.v.01
# 7              5    duck            5              duck.v.02
# 8              6    duck            6               dip.v.10
# 9              7    duck            7             hedge.v.01
# 10             0    bird            0              bird.n.01
# 11             1    bird            1              bird.n.02
# 12             2    bird            2              dame.n.01
# 13             3    bird            3               boo.n.01
# 14             4    bird            4       shuttlecock.n.01
# 15             5    bird            5              bird.v.01
# 16             0     eye            0               eye.n.01
# 17             1     eye            1               eye.n.02
# 18             2     eye            2               eye.n.03
# 19             3     eye            3            center.n.01
# 20             4     eye            4               eye.n.05
# 21             5     eye            5               eye.v.01
# 22             0    nose            0              nose.n.01
# 23             1    nose            1              nose.n.02
# 24             2    nose            2              nose.n.03
# 25             3    nose            3              nose.n.04
# 26             4    nose            4              nose.n.05
# 27             5    nose            5              nose.n.06
# 28             6    nose            6              nose.n.07
# 29             7    nose            7            nozzle.n.01
# ...          ...     ...          ...                    ...
# 5332           1    time            1              time.n.02
# 5333           2    time            2              time.n.03
# 5334           3    time            3              time.n.04
# 5335           4    time            4              time.n.05
# 5336           5    time            5              time.n.06
# 5337           6    time            6        clock_time.n.01
# 5338           7    time            7  fourth_dimension.n.01
# 5339           8    time            8             meter.n.04
# 5340           9    time            9       prison_term.n.01
# 5341          10    time           10             clock.v.01
# 5342          11    time           11              time.v.02
# 5343          12    time           12              time.v.03
# 5344          13    time           13              time.v.04
# 5345          14    time           14              time.v.05
# 5346           0    next            0         following.s.02
# 5347           1    next            1          adjacent.s.01
# 5348           2    next            2            future.s.03
# 5349           3    next            3              next.r.01
# 5350           0    same            0              lapp.n.01
# 5351           1    same            1              lapp.n.02
# 5352           2    same            2              same.a.01
# 5353           3    same            3              same.a.02
# 5354           4    same            4              like.a.02
# 5355           5    same            5              same.s.04
# 5356           0  circus            0            circus.n.01
# 5357           1  circus            1            circus.n.02
# 5358           2  circus            2            circus.n.03
# 5359           3  circus            3            circus.n.04
# 5360           4  circus            4            circus.n.05
# 5361           5  circus            5            circus.n.06
#
#                  lexname pos  \
# 0             noun.event   n
# 1     verb.communication   v
# 2            noun.animal   n
# 3          noun.quantity   n
# 4              noun.food   n
# 5          noun.artifact   n
# 6            verb.motion   v
# 7            verb.motion   v
# 8            verb.motion   v
# 9     verb.communication   v
# 10           noun.animal   n
# 11             noun.food   n
# 12           noun.person   n
# 13    noun.communication   n
# 14         noun.artifact   n
# 15      verb.competition   v
# 16             noun.body   n
# 17        noun.cognition   n
# 18        noun.cognition   n
# 19         noun.location   n
# 20         noun.artifact   n
# 21       verb.perception   v
# 22             noun.body   n
# 23         noun.artifact   n
# 24         noun.artifact   n
# 25         noun.quantity   n
# 26    noun.communication   n
# 27        noun.cognition   n
# 28        noun.cognition   n
# 29         noun.artifact   n
# ...                  ...  ..
# 5332           noun.time   n
# 5333           noun.time   n
# 5334           noun.time   n
# 5335           noun.Tops   n
# 5336          noun.event   n
# 5337           noun.time   n
# 5338           noun.time   n
# 5339      noun.attribute   n
# 5340           noun.time   n
# 5341         verb.change   v
# 5342      verb.cognition   v
# 5343      verb.cognition   v
# 5344         verb.change   v
# 5345         verb.change   v
# 5346             adj.all   s
# 5347             adj.all   s
# 5348             adj.all   s
# 5349             adv.all   r
# 5350         noun.person   n
# 5351  noun.communication   n
# 5352             adj.all   a
# 5353             adj.all   a
# 5354             adj.all   a
# 5355             adj.all   s
# 5356          noun.group   n
# 5357            noun.act   n
# 5358            noun.act   n
# 5359       noun.artifact   n
# 5360       noun.artifact   n
# 5361         noun.animal   n
#
#                                              definition  \
# 0     the roaring sound made by a motor that is runn...
# 1     make a loud, roaring sound, as of a car engine...
# 2     small wild or domesticated web-footed broad-bi...
# 3             (cricket) a score of nothing by a batsman
# 4                    flesh of a duck (domestic or wild)
# 5     a heavy cotton fabric of plain weave; used for...
# 6     to move (the head or body) quickly downwards o...
# 7                           submerge or plunge suddenly
# 8                                     dip into a liquid
# 9     avoid or try to avoid fulfilling, answering, o...
# 10    warm-blooded egg-laying vertebrates characteri...
# 11    the flesh of a bird or fowl (wild or domestic)...
# 12                   informal terms for a (young) woman
# 13    a cry or noise made to express displeasure or ...
# 14    badminton equipment consisting of a ball of co...
# 15       watch and study birds in their natural habitat
# 16                                   the organ of sight
# 17    good discernment (either visually or as if vis...
# 18                            attention to what is seen
# 19    an area that is approximately central within s...
# 20                a small hole or loop (as in a needle)
# 21                                              look at
# 22    the organ of smell and entrance to the respira...
# 23    a front that resembles a human nose (especiall...
# 24    the front or forward projection of a tool or w...
# 25                                     a small distance
# 26                          a symbol of inquisitiveness
# 27           the sense of smell (especially in animals)
# 28                                      a natural skill
# 29    a projecting spout from which a fluid is disch...
# ...                                                 ...
# 5332  a period of time considered as a resource unde...
# 5333  an indefinite period (usually marked by specif...
# 5334                                  a suitable moment
# 5335  the continuum of experience in which events pa...
# 5336     a person's experience on a particular occasion
# 5337   a reading of a point in time as given by a clock
# 5338  the fourth coordinate that is required (along ...
# 5339  rhythm as given by division into parts of equa...
# 5340        the period of time a prisoner is imprisoned
# 5341  measure the time or duration of an event or ac...
# 5342             assign a time for an activity or event
# 5343           set the speed, duration, or execution of
# 5344                        regulate or set the time of
# 5345  adjust so that a force is applied and an actio...
# 5346             immediately following in time or order
# 5347  nearest in space or position; immediately adjo...
# 5348  (of elected officers) elected but not yet serving
# 5349      at the time or occasion immediately following
# 5350  a member of an indigenous nomadic people livin...
# 5351  the language of nomadic Lapps in northern Scan...
# 5352                                   same in identity
# 5353  closely similar or comparable in kind or quali...
# 5354                           equal in amount or value
# 5355                   unchanged in character or nature
# 5356  a travelling company of entertainers; includin...
# 5357  a performance given by a traveling company of ...
# 5358  a frenetic disorganized (and often comic) dist...
# 5359  (antiquity) an open-air stadium for chariot ra...
# 5360  an arena consisting of an oval or circular are...
# 5361            a genus of haws comprising the harriers
#
#                                                examples
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6        Before he could duck, another stone struck him
# 7                                                   NaN
# 8                               He dipped into the pool
# 9     He dodged the issue;she skirted the problem;Th...
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17    she has an eye for fresh talent;he has an arti...
# 18                            he tried to catch her eye
# 19    it is in the center of town;they ran forward i...
# 20               the thread wouldn't go through the eye
# 21                                                  NaN
# 22                            he has a cold in the nose
# 23          the nose of the rocket heated up on reentry
# 24                  he ducked under the nose of the gun
# 25                     my horse lost the race by a nose
# 26                             keep your nose out of it
# 27                            the hound has a good nose
# 28                         he has a nose for good deals
# 29                                                  NaN
# ...                                                 ...
# 5332  take time to smell the roses;I didn't have tim...
# 5333  he waited a long time;the time of year for pla...
# 5334                                   it is time to go
# 5335                                                NaN
# 5336  he had a time holding back the tears;they had ...
# 5337  do you know what time it is?;the time is 10 o'...
# 5338                                                NaN
# 5339                                                NaN
# 5340  he served a prison term of 15 months;his sente...
# 5341                             he clocked the runners
# 5342  The candidate carefully timed his appearance a...
# 5343  we time the process to manufacture our cars ve...
# 5344                                     time the clock
# 5345  The good player times his swing so as to hit t...
# 5346  the following day;next in line;the next presid...
# 5347  had adjacent rooms;in the next room;the person...
# 5348                                 our next president
# 5349                  next the doctor examined his back
# 5350                                                NaN
# 5351                                                NaN
# 5352  the same man I saw yesterday;never wore the sa...
# 5353  curtains the same color as the walls;two girls...
# 5354  like amounts;equivalent amounts;the same amoun...
# 5355  the village stayed the same;his attitude is th...
# 5356           he ran away from home to join the circus
# 5357       the children always love to go to the circus
# 5358  it was so funny it was a circus;the whole occa...
# 5359                                                NaN
# 5360  they used the elephants to help put up the circus
# 5361                                                NaN
#
# [5362 rows x 8 columns]

# %%
import itertools
cdi_counterlist=[]

# for index, row in cdi.iterrows():
#     trigger=False
#     for index2, row2 in sentences.iterrows():
#         while trigger==False:
#             if row2['correct_term']==row['word']:
#                 print(row2['correct_term'],row['word'])
#                 trigger=True

example_sentences=[]
for index, row in cdi.iterrows():
    word=row['word']
    sentences_ref=sentences[sentences['correct_term']==word]
#     print(list(sentences_ref['sense_tag_list'])[0])
#     print(row['name']+'.'+row['word'])
    try:
        index_ref=list(sentences_ref['sense_tag_list'])[0].index("'"+row['name']+'.'+row['word']+"'")
        real_index=list(sentences_ref[1])[0][index_ref]
        sentence_to_be_printed=semcor.sents()[real_index]
    except:
        sentence_to_be_printed=[]
    example_sentences.append(sentence_to_be_printed)
# example_sentences

# %%
cdi['semcor_examples']=example_sentences

# %%
cdi.to_csv("cdi_semcored.csv")

# %%
cdi_counterlist
# Out:
# [2, 2, 2, 3]

# %%
index=list(sentences[sentences['correct_term']=='duck'][1])[0][2]

# %%
sentences[sentences['correct_term']=='duck']
# Out:
#              0                                   1 correct_term
# 39618  'duck',  [7670, 10491, 18734, 19079, 20087]         duck

# %%
semcor.sents()[18734]
# semcor.sents()[index]
# Out:
# ['There',
#  'was',
#  'not',
#  'enough',
#  'room',
#  'to',
#  'make',
#  'the',
#  'usual',
#  'vertical',
#  'bomb',
#  'run',
#  '.']

# %%
import pandas as pd
dd=pd.read_csv("sentences_taggedsense.csv")

# %%
semcor.sents()[4098]
# Out:
# ['Occasional',
#  'tubules',
#  'contained',
#  'hyaline',
#  'casts',
#  'admixed',
#  'with',
#  'neutrophils',
#  '.']

# %%
dd
# Out:
#        Unnamed: 0                   0  \
# 0               0           'mounds',
# 1               1    'vulnerability',
# 2               2         'outlying',
# 3               3        'delegated',
# 4               4       'previously',
# 5               5       'accelerate',
# 6               6           'casals',
# 7               7        'prognosis',
# 8               8             'clue',
# 9               9       'high-class',
# 10             10      'insecticide',
# 11             11             'grin',
# 12             12      'agglutinins',
# 13             13            'friar',
# 14             14             'tory',
# 15             15           'versed',
# 16             16         'pianists',
# 17             17         'softened',
# 18             18         'equipped',
# 19             19        'provisons',
# 20             20       'excellence',
# 21             21           'doings',
# 22             22          'buckled',
# 23             23       'surprising',
# 24             24          'invaded',
# 25             25        'coalesces',
# 26             26       'isothermal',
# 27             27   'differentiable',
# 28             28            ['none',
# 29             29           '300000',
# ...           ...                 ...
# 41691       41691         'chartres',
# 41692       41692          'rubdown',
# 41693       41693         'tangency',
# 41694       41694           'rifled',
# 41695       41695       'absolutely',
# 41696       41696             'russ',
# 41697       41697         'anterior',
# 41698       41698   'asymptotically',
# 41699       41699        'whitfield',
# 41700       41700      'development',
# 41701       41701            'moune',
# 41702       41702        'imbroglio',
# 41703       41703            'bruno',
# 41704       41704           'defeat',
# 41705       41705            'pouch',
# 41706       41706          'article',
# 41707       41707          'algebra',
# 41708       41708        'treasurer',
# 41709       41709         'twirling',
# 41710       41710          'hurrays',
# 41711       41711     'clean-shaven',
# 41712       41712         'kroening',
# 41713       41713  'micrometeoritic',
# 41714       41714      'sweethearts',
# 41715       41715       'grudgingly',
# 41716       41716             'coup',
# 41717       41717     'ridiculously',
# 41718       41718        'incidence',
# 41719       41719             'side',
# 41720       41720             'didn',
#
#                                                        1     correct_term  \
# 0                                                 [4098]           mounds
# 1             [13638, 13639, 13640, 30648, 30685, 30686]    vulnerability
# 2                                         [17462, 26925]         outlying
# 3                                  [16894, 34405, 35521]        delegated
# 4      [160, 1433, 2007, 3144, 3286, 3766, 3919, 4751...       previously
# 5                             [3564, 4468, 26313, 30037]       accelerate
# 6                                                [23876]           casals
# 7                                                [37087]        prognosis
# 8      [1297, 2800, 4791, 6589, 6695, 14196, 14381, 2...             clue
# 9                                                [35929]       high-class
# 10                                               [32908]      insecticide
# 11     [699, 12905, 17407, 18549, 18732, 26230, 28065...             grin
# 12                                          [3909, 3986]      agglutinins
# 13                                               [28980]            friar
# 14                                  [2742, 34150, 34151]             tory
# 15                                               [24272]           versed
# 16                                         [1960, 23842]         pianists
# 17                          [10671, 23341, 31581, 33814]         softened
# 18     [2625, 3599, 3604, 3607, 3702, 4684, 6221, 117...         equipped
# 19                                               [15163]        provisons
# 20     [13912, 22415, 22417, 24234, 24235, 24244, 281...       excellence
# 21                                         [5897, 21477]           doings
# 22                                               [38191]          buckled
# 23     [2161, 4153, 5770, 5890, 5891, 9629, 14309, 14...       surprising
# 24             [4646, 11330, 12901, 24389, 27090, 33917]          invaded
# 25                                               [25378]        coalesces
# 26                                                [3368]       isothermal
# 27                                    [4920, 4921, 4925]   differentiable
# 28     [1914, 10184, 17552, 18098, 25162, 25710, 2979...             none
# 29              [142, 14782, 15883, 25947, 26706, 30700]           300000
# ...                                                  ...              ...
# 41691                                            [13761]         chartres
# 41692                                            [32276]          rubdown
# 41693                              [35237, 35249, 35251]         tangency
# 41694                                            [31430]           rifled
# 41695  [1531, 2632, 2863, 2871, 2877, 5512, 5525, 554...       absolutely
# 41696  [276, 18808, 18812, 18820, 18836, 18851, 18856...             russ
# 41697                   [4452, 4469, 4772, 33204, 33208]         anterior
# 41698                                             [3332]   asymptotically
# 41699                                              [354]        whitfield
# 41700  [194, 970, 1439, 1659, 1745, 1773, 1783, 1792,...      development
# 41701                                            [20887]            moune
# 41702                                            [24907]        imbroglio
# 41703                                            [34054]            bruno
# 41704  [2740, 5224, 5240, 13210, 13221, 13256, 13702,...           defeat
# 41705                                             [9001]            pouch
# 41706  [1572, 1573, 1585, 7884, 11640, 11836, 15180, ...          article
# 41707                                       [4917, 4930]          algebra
# 41708  [124, 5744, 5792, 5874, 20529, 21481, 21773, 2...        treasurer
# 41709                               [2494, 10682, 34328]         twirling
# 41710                              [38884, 38887, 38892]          hurrays
# 41711                                             [9044]     clean-shaven
# 41712                                            [31204]         kroening
# 41713                                       [3691, 3715]  micrometeoritic
# 41714                                            [12856]      sweethearts
# 41715                [19434, 27915, 37235, 37821, 37928]       grudgingly
# 41716                              [13289, 21134, 25476]             coup
# 41717                                     [18968, 26327]     ridiculously
# 41718          [4310, 11840, 11848, 11849, 11930, 35501]        incidence
# 41719  [436, 505, 677, 694, 942, 987, 1207, 1397, 153...             side
# 41720                                            [19136]             didn
#
#                                           sense_tag_list
# 0                                                     []
# 1      ["'vulnerability.n.01.vulnerability'", "'vulne...
# 2                           ["'outlying.s.01.outlying'"]
# 3                                                     []
# 4      ["'previously.r.01.previously'", "'previously....
# 5      ["'accelerated.s.01.accelerated'", "'accelerat...
# 6                                                     []
# 7                          ["'prognosis.n.01.forecast'"]
# 8      ["'hint.n.02.clue'", "'hint.n.02.clue'", "'hin...
# 9                                                     []
# 10                                                    []
# 11     ["'smile.n.01.grin'", "'chagrin.n.01.chagrin'"...
# 12                                                    []
# 13                                                    []
# 14     ["'depository_financial_institution.n.01.bank'...
# 15                                                    []
# 16                                                    []
# 17                                                    []
# 18     ["'equipped.a.01.equipped'", "'ill-equipped.s....
# 19                                                    []
# 20     ["'excellence.n.01.excellence'", "'excellence....
# 21                                                    []
# 22                                                    []
# 23     ["'surprising.a.01.surprising'", "'amazingly.r...
# 24                                                    []
# 25                                                    []
# 26                      ["'isothermal.s.01.isothermal'"]
# 27     ["'differentiable.a.01.differentiable'", "'dif...
# 28     ["'nonexistent.a.01.nonexistent'", "'nonequiva...
# 29                                                    []
# ...                                                  ...
# 41691                                                 []
# 41692                                                 []
# 41693                                                 []
# 41694                                                 []
# 41695  ["'absolutely.r.01.perfectly'", "'absolutely.r...
# 41696  ["'russian.n.02.Russian'", "'russian.n.01.Russ...
# 41697  ["'anterior.s.02.prior'", "'anterior.s.02.prio...
# 41698           ["'asymptotically.r.01.asymptotically'"]
# 41699                                                 []
# 41700  ["'water_development.n.01.water_development'",...
# 41701                                                 []
# 41702                                                 []
# 41703                                                 []
# 41704  ["'get_the_better_of.v.01.defeat'", "'defeat.n...
# 41705  ["'pouch.n.02.pocket'", "'pouch.n.02.pocket'",...
# 41706  ["'article.n.01.article'", "'article.n.01.arti...
# 41707  ["'algebraically.r.01.algebraically'", "'algeb...
# 41708  ["'state_treasurer.n.01.state_treasurer'", "'t...
# 41709                   ["'twirlingly.r.01.twirlingly'"]
# 41710                                                 []
# 41711               ["'clean-shaven.s.01.clean-shaven'"]
# 41712                                                 []
# 41713  ["'micrometeoritic.a.01.micrometeoritic'", "'m...
# 41714                                                 []
# 41715                   ["'grudgingly.r.01.grudgingly'"]
# 41716  ["'couple.n.02.couple'", "'couple.n.02.couple'...
# 41717                  ["'laughably.r.01.ridiculously'"]
# 41718  ["'coincidence.n.01.coincidence'", "'coinciden...
# 41719  ["'consider.v.04.consider'", "'besides.r.02.al...
# 41720                                                 []
#
# [41721 rows x 5 columns]
